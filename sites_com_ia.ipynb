# %%
from langchain_community.document_loaders import WebBaseLoader

loader = WebBaseLoader("https://asimov.academy/")
lista_documentos = loader.load()
print(lista_documentos)
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.
# ...

# %%
print(lista_documentos[0].page_content)
# Out:
#     Home | Asimov Academy
#   Ir para o conteúdoasimovTrilhasTrilha Aplicações IA com PythonTrilha Dashboards com PythonTrilha Python OfficeTrilha Visão ComputacionalTrilha Data Science e Machine LearningTrilha Análise e Visualização de DadosTrilha Trading QuantitativoCursosProjetosConteúdos gratuitosCurso Python para iniciantesCurso Python para IACurso Python para DadosBlogTutoriaisPara empresas
#  MenuTrilhasTrilha Aplicações IA com PythonTrilha Dashboards com PythonTrilha Python OfficeTrilha Visão ComputacionalTrilha Data Science e Machine LearningTrilha Análise e Visualização de DadosTrilha Trading QuantitativoCursosProjetosConteúdos gratuitosCurso Python para iniciantesCurso Python para IACurso Python para DadosBlogTutoriaisPara empresas
#
#
#
#
# Entrar
#
#
#
#
# Matricule-se
#
# asimov
# ...

# %%
documento = ''
for doc in lista_documentos:
    documento += doc.page_content
print(documento)
# Out:
#     Home | Asimov Academy
#   Ir para o conteúdoasimovTrilhasTrilha Aplicações IA com PythonTrilha Dashboards com PythonTrilha Python OfficeTrilha Visão ComputacionalTrilha Data Science e Machine LearningTrilha Análise e Visualização de DadosTrilha Trading QuantitativoCursosProjetosConteúdos gratuitosCurso Python para iniciantesCurso Python para IACurso Python para DadosBlogTutoriaisPara empresas
#  MenuTrilhasTrilha Aplicações IA com PythonTrilha Dashboards com PythonTrilha Python OfficeTrilha Visão ComputacionalTrilha Data Science e Machine LearningTrilha Análise e Visualização de DadosTrilha Trading QuantitativoCursosProjetosConteúdos gratuitosCurso Python para iniciantesCurso Python para IACurso Python para DadosBlogTutoriaisPara empresas
#
#
#
#
# Entrar
#
#
#
#
# Matricule-se
#
# asimov
# ...

# %%
import os
from langchain_groq import ChatGroq
from langchain.prompts import ChatPromptTemplate

api_key = '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'
os.environ['GROQ_API_KEY'] = api_key

# %%
from langchain_groq import ChatGroq

chat = ChatGroq(model = 'llama-3.1-70b-versatile')

# %%
template = ChatPromptTemplate.from_messages([
    ('system', 'Você é um assistente virtual chamado Erick e tem acesso às seguintes informações para fornecer suas respostas: {documentos_informados}'),
    ('user', '{input}')
])
chain = template | chat
resposta = chain.invoke({'documentos_informados': documento, 'input': 'Quais as trilhas disponíveis na Asimov?'})

# %%
print(resposta.content)
# Out:
# A Asimov oferece as seguintes trilhas de conhecimento:
#
# 1. **Trilha Aplicações IA com Python**: Esta trilha é focada em Inteligência Artificial e permite que os alunos criem aplicações de IA personalizadas.
# 2. **Trilha Dashboards Interativos com Python**: Esta trilha é dedicada à criação de dashboards interativos com Python.
# 3. **Trilha Python Office**: Esta trilha é focada em automação de tarefas com Python e permite que os alunos aprendam a utilizar ferramentas do Python para automatizar tarefas.
# 4. **Trilha Visão Computacional**: Esta trilha é focada em Visão Computacional e permite que os alunos criem sistemas inteligentes de análise de imagens e vídeo.
# 5. **Trilha Data Science e Machine Learning**: Esta trilha é focada em Análise de Dados e Aprendizado de Máquina, e permite que os alunos dominem análise complexas, modelos de ML e predições com Python.
# ...
